# %%
import sys
import os
sys.path.append(os.path.abspath('../scripts'))
from load_data import load_data_from_postgres, load_data_using_sqlalchemy
from prepare_data import clean_data

# %%
# Run the query
query = "SELECT * FROM xdr_data;"  # Replace with actual table name
df = load_data_using_sqlalchemy(query)

if df is not None:
    print("Successfully loaded the data")
    display(df.head())
else:
    print("Failed to load data.")
# Out:
# Successfully loaded the data
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# ...

# %%
    # Clean the data
    df_cleaned = clean_data(df)

    # Display the cleaned data
    display(df_cleaned.head())
# Out:
#       Bearer Id               Start  Start ms                 End  End ms  \
# 0  1.311448e+19 2019-04-04 12:01:00     770.0 2019-04-25 14:35:00   662.0
# 1  1.311448e+19 2019-04-09 13:04:00     235.0 2019-04-25 08:15:00   606.0
# 2  1.311448e+19 2019-04-09 17:42:00       1.0 2019-04-25 11:58:00   652.0
# 3  1.311448e+19 2019-04-10 00:31:00     486.0 2019-04-25 07:36:00   171.0
# 4  1.311448e+19 2019-04-12 20:10:00     565.0 2019-04-25 10:40:00   954.0
#
#       Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  92261.223185  2.082014e+14   3.366496e+10  3.552121e+13
# 1  92261.223185  2.082019e+14   3.368185e+10  3.579401e+13
# 2  92261.223185  2.082015e+14   3.365762e+10  3.528151e+13
# 3  92261.223185  2.082014e+14   3.365762e+10  3.535661e+13
# 4  92261.223185  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# ...

# %% [markdown]
# Task 3 on Experience Analytics

# %% [markdown]
# Task 3.1 - Aggregate Network Parameters and Device Information

# %%
import pandas as pd
import numpy as np


df_cleaned['TCP DL Retrans. Vol (Bytes)'].fillna(df_cleaned['TCP DL Retrans. Vol (Bytes)'].mean(), inplace=True)
df_cleaned['TCP UL Retrans. Vol (Bytes)'].fillna(df_cleaned['TCP UL Retrans. Vol (Bytes)'].mean(), inplace=True)
df_cleaned['Avg RTT DL (ms)'].fillna(df_cleaned['Avg RTT DL (ms)'].mean(), inplace=True)
df_cleaned['Avg RTT UL (ms)'].fillna(df_cleaned['Avg RTT UL (ms)'].mean(), inplace=True)
df_cleaned['Avg Bearer TP DL (kbps)'].fillna(df_cleaned['Avg Bearer TP DL (kbps)'].mean(), inplace=True)
df_cleaned['Avg Bearer TP UL (kbps)'].fillna(df_cleaned['Avg Bearer TP UL (kbps)'].mean(), inplace=True)
df_cleaned['Handset Type'].fillna(df_cleaned['Handset Type'].mode()[0], inplace=True)

# Aggregate per customer (MSISDN/Number)
customer_agg = df.groupby('MSISDN/Number').agg({
    'TCP DL Retrans. Vol (Bytes)': 'mean',
    'TCP UL Retrans. Vol (Bytes)': 'mean',
    'Avg RTT DL (ms)': 'mean',
    'Avg RTT UL (ms)': 'mean',
    'Avg Bearer TP DL (kbps)': 'mean',
    'Avg Bearer TP UL (kbps)': 'mean',
    'Handset Type': 'first'  
}).reset_index()


customer_agg['Avg TCP Retransmission'] = (customer_agg['TCP DL Retrans. Vol (Bytes)'] + customer_agg['TCP UL Retrans. Vol (Bytes)']) / 2
customer_agg['Avg RTT'] = (customer_agg['Avg RTT DL (ms)'] + customer_agg['Avg RTT UL (ms)']) / 2
customer_agg['Avg Throughput'] = (customer_agg['Avg Bearer TP DL (kbps)'] + customer_agg['Avg Bearer TP UL (kbps)']) / 2


display(customer_agg[['MSISDN/Number', 'Avg TCP Retransmission', 'Avg RTT', 'Handset Type', 'Avg Throughput']])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9208\2677127809.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned['TCP UL Retrans. Vol (Bytes)'].fillna(df_cleaned['TCP UL Retrans. Vol (Bytes)'].mean(), inplace=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_9208\2677127809.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# Task 3.2 - Computing Top, Bottom, and Most Frequent Values

# %%
def compute_stats(column):
    top_values = column.nlargest(10)
    bottom_values = column.nsmallest(10)
    most_frequent_values = column.value_counts().nlargest(10)
    return top_values, bottom_values, most_frequent_values

# TCP Values
tcp_dl_top, tcp_dl_bottom, tcp_dl_frequent = compute_stats(df['TCP DL Retrans. Vol (Bytes)'])
tcp_ul_top, tcp_ul_bottom, tcp_ul_frequent = compute_stats(df['TCP UL Retrans. Vol (Bytes)'])

# RTT Values
rtt_dl_top, rtt_dl_bottom, rtt_dl_frequent = compute_stats(df['Avg RTT DL (ms)'])
rtt_ul_top, rtt_ul_bottom, rtt_ul_frequent = compute_stats(df['Avg RTT UL (ms)'])

# Throughput Values
tp_dl_top, tp_dl_bottom, tp_dl_frequent = compute_stats(df['Avg Bearer TP DL (kbps)'])
tp_ul_top, tp_ul_bottom, tp_ul_frequent = compute_stats(df['Avg Bearer TP UL (kbps)'])

# Display results for TCP
print("Top 10 TCP DL values:", tcp_dl_top)
print("Bottom 10 TCP DL values:", tcp_dl_bottom)
print("Most frequent TCP DL values:", tcp_dl_frequent)
# Out:
# Top 10 TCP DL values: 6421      50021024.0
# 138739    49991791.0
# 66754     49986834.0
# 136231    49986038.0
# 76025     49969605.0
# 77840     49921268.0
# 143262    49833677.0
# 116528    49779123.0
# 9726      49777538.0
# 139884    49663906.0
# Name: TCP DL Retrans. Vol (Bytes), dtype: float64
# Bottom 10 TCP DL values: 59717     2.0
# 125094    2.0
# 2850      4.0
# 39610     4.0
# 52488     4.0
# 60376     4.0
# 60426     4.0
# 75093     4.0
# 100314    4.0
# 143429    4.0
# Name: TCP DL Retrans. Vol (Bytes), dtype: float64
# Most frequent TCP DL values: TCP DL Retrans. Vol (Bytes)
# 2.080991e+07    88146
# 1.382504e+07     2525
# 1.330000e+03      433
# 2.660000e+03      219
# 3.800000e+01      200
# 9.200000e+01      192
# 1.318000e+03      156
# 5.430000e+02      133
# 3.990000e+03      114
# 7.600000e+01      108
# Name: count, dtype: int64

# %% [markdown]
# Task 3.3 - Analyzing Distribution of Experience Metrics

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))

top_5_throughput_handsets = customer_agg.groupby('Handset Type')['Avg Throughput'].mean().nlargest(5).reset_index()

sns.barplot(x='Avg Throughput', y='Handset Type', data=top_5_throughput_handsets, order=top_5_throughput_handsets['Handset Type'])
plt.title('Top 5 Handset Types by Average Throughput')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()


plt.figure(figsize=(12, 8))

top_5_tcp_handsets = customer_agg.groupby('Handset Type')['Avg TCP Retransmission'].mean().nlargest(5).reset_index()


sns.barplot(x='Avg TCP Retransmission', y='Handset Type', data=top_5_tcp_handsets, order=top_5_tcp_handsets['Handset Type'])
plt.title('Top 5 Handset Types by Average TCP Retransmission')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9208\2691025932.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   top_5_throughput_handsets = customer_agg.groupby('Handset Type')['Avg Throughput'].mean().nlargest(5).reset_index()
# C:\Users\USER\AppData\Local\Temp\ipykernel_9208\2691025932.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   top_5_tcp_handsets = customer_agg.groupby('Handset Type')['Avg TCP Retransmission'].mean().nlargest(5).reset_index()

# %% [markdown]
# Task 3.4 - K-means Clustering for User Segmentation

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Features for clustering
X = customer_agg[['Avg Throughput', 'Avg RTT', 'Avg TCP Retransmission']]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


kmeans = KMeans(n_clusters=3, random_state=42)
customer_agg['Cluster'] = kmeans.fit_predict(X_scaled)

print("Cluster Centers:", kmeans.cluster_centers_)
print("Cluster Label Counts:", customer_agg['Cluster'].value_counts())
# Out:
# Cluster Centers: [[ 0.95563257 -0.02609231 -1.20911931]
#  [-0.50259952 -0.74364716  0.63760958]
#  [-0.42329975  1.32140908  0.53265465]]
# Cluster Label Counts: Cluster
# 1    38130
# 0    29848
# 2    22059
# Name: count, dtype: int64

# %%
# Calculate the average throughput for each cluster
cluster_throughput = customer_agg.groupby('Cluster')['Avg Throughput'].mean().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(x='Cluster', y='Avg Throughput', data=cluster_throughput)
plt.title('Average Throughput per Cluster')
plt.xlabel('Cluster')
plt.ylabel('Average Throughput (kbps)')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count the number of users in each cluster
cluster_counts = customer_agg['Cluster'].value_counts().reset_index()
cluster_counts.columns = ['Cluster', 'Number of Users']

plt.figure(figsize=(8, 6))
sns.barplot(x='Cluster', y='Number of Users', data=cluster_counts)
plt.title('Number of Users per Cluster')
plt.xlabel('Cluster')
plt.ylabel('Number of Users')
plt.tight_layout()
plt.show()
